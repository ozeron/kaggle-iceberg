# %%
import pickle
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15.0, 12.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# COPIED
import sys
import os
PROJECT_HOME = os.path.normpath(os.path.join(os.getcwd(), '../'))
if PROJECT_HOME not in sys.path:
    sys.path.append(PROJECT_HOME)
from src.utils import open_history

# %%
# os.listdir(PROJECT_HOME)
data = open_history('basic-conv-keras')
df = pd.DataFrame(data)
df.iloc[5:].plot(y=['loss', 'val_loss'])
# Out:
# /home/ozeron/.virtualenvs/p3/lib/python3.5/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
